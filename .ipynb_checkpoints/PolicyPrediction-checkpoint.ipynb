# %%
import pandas as pd
import re
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import numpy as np

df = pd.read_csv("covid19_tweets.csv")

# exTweet = "strive to promote Truth with Integrity. https://t.co/pOqdhk6Mhg"
def clean_tweet(text):
    ''' Remove links and symbols, make text lowercase'''
    text = text.lower()
    text = re.sub('http\S+', '', text)
    text = re.sub('[^0-9a-zA-Z ]+', '', text)
    return text

df['text_clean'] = df['text'].apply(str).apply(lambda x: clean_tweet(x))

# Print locations
print(df["user_location"].value_counts().index[0:500])

# Get Sentiment from Vader
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
df["Score"] = df["text_clean"].apply(lambda x: sid.polarity_scores(x)) 
print(df["Score"])
# Out:
# Index(['India', 'United States', 'New Delhi, India', 'Mumbai, India',
#        'Washington, DC', 'London, England', 'United Kingdom', 'London',
#        'New York, NY', 'Australia',
#        ...
#        'Oklahoma', 'Bethesda, MD', 'Federal Capital Territory, Nig',
#        'Hawaii, USA', 'SoCal', 'Greenville, SC', 'Somewhere', 'City of London',
#        'Abuja', 'Makati, Philippines'],
#       dtype='object', length=500)
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Caleb\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# 0         {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'comp...
# 1         {'neg': 0.065, 'neu': 0.829, 'pos': 0.106, 'co...
# 2         {'neg': 0.116, 'neu': 0.884, 'pos': 0.0, 'comp...
# 3         {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 4         {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'comp...
#                                 ...
# ...

# %%
df['compoundScore'] = df["Score"].apply(lambda x: x['compound'])
df['compoundScore']
# Out:
# 0         0.4939
# 1         0.2263
# 2        -0.2732
# 3         0.7351
# 4         0.3182
#            ...
# 179103    0.4404
# 179104   -0.2263
# 179105   -0.2023
# 179106    0.5574
# 179107   -0.2960
# Name: compoundScore, Length: 179108, dtype: float64

# %%
df = df[(df['compoundScore']>0.01) | (df['compoundScore']<-0.01)]
df.compoundScore
# Out:
# 0         0.4939
# 2        -0.2732
# 3         0.7351
# 4         0.3182
# 5        -0.4445
#            ...
# 179095   -0.2960
# 179097   -0.7845
# 179103    0.4404
# 179106    0.5574
# 179107   -0.2960
# Name: compoundScore, Length: 94545, dtype: float64

# %%
import matplotlib.pyplot as plt

df['date'] = pd.to_datetime(df['date']).dt.date
dates = np.array(df['date'])
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 18
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size

plt.plot(df.groupby('date').mean()['compoundScore'])

# %%
df.groupby('date').mean()['compoundScore']
# Out:
# date
# 2020-07-24    0.062666
# 2020-07-25    0.102803
# 2020-07-26    0.075988
# 2020-07-27    0.097453
# 2020-07-28    0.091249
# 2020-07-29    0.128200
# 2020-07-30    0.033034
# 2020-07-31    0.128400
# 2020-08-01    0.081751
# 2020-08-02    0.055023
# 2020-08-04    0.083865
# 2020-08-06    0.138800
# 2020-08-07    0.174001
# 2020-08-08    0.106111
# 2020-08-09    0.036733
# 2020-08-10    0.120883
# 2020-08-11    0.153482
# 2020-08-12    0.108843
# 2020-08-13    0.142385
# 2020-08-14    0.072063
# 2020-08-16    0.000419
# 2020-08-17    0.091335
# 2020-08-18    0.106624
# 2020-08-22    0.090604
# 2020-08-29    0.047471
# 2020-08-30    0.036712
# Name: compoundScore, dtype: float64

# %%
df['roundedCompoundScore'] = df['compoundScore'].round(1)
plt.plot(df.groupby('roundedCompoundScore').count())

# %%
df[(df['compoundScore']>0.25) | (df['compoundScore']<-0.5)]
# Out:
#                                 user_name               user_location  \
# 0                                  ᏉᎥ☻լꂅϮ                  astroworld
# 3                             ethel mertz        Stuck in the Middle
# 4                                DIPR-J&K           Jammu and Kashmir
# 8                       Prathamesh Bendre                         NaN
# 9       Member of Christ 🇨🇳🇺🇸🇮🇳🇮🇩🇧🇷🇳🇬🇧🇩🇷🇺  👇🏻location at link below👇🏻
# ...                                   ...                         ...
# 179085                     3D Innovations            Honolulu, Hawaii
# 179090                   Randy Richardson              Des Moines, IA
# 179097                          rainmaker                         NaN
# 179103             AJIMATI AbdulRahman O.             Ilorin, Nigeria
# 179106                      Gary DelPonte               New York City
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# ...

# %%
x = df[(df['compoundScore']>0.25) | (df['compoundScore']<0.5)]
x.text[0]
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# <ipython-input-1-6eb3bf894346> in <module>
# ----> 1 x = df[(df['compoundScore']>0.25) | (df['compoundScore']<0.5)]
#       2 x.text[0]
#
# NameError: name 'df' is not defined
